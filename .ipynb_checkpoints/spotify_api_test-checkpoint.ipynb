# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
cid = '65035d33942c4248bc6829d1d661f8e3'
secret = '9573b7244533425ebb417750634759ed'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager
= client_credentials_manager)

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(0,1000,50):
    track_results = sp.search(q='year:2022',type='track',market='US', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])

# %%
country_code = 'US'
limit = 20
playlists = sp.category_playlists(category_id='toplists', country=country_code)['playlists']['items']
# Iterate over the playlists and retrieve their tracks
for playlist in playlists:
    playlist_id = playlist['id']
    playlist_name = playlist['name']
    # Get the tracks of the playlist
    tracks = sp.playlist_tracks(playlist_id, limit=limit)['items']
    # Print the playlist name and its top 20 tracks
    print(f'Playlist: {playlist_name}')
    for track in tracks:
        track_name = track['track']['name']
        artist_name = track['track']['artists'][0]['name']
        print(f'Track: {track_name} - Artist: {artist_name}')
    print('---')
# Out:
# Playlist: Today's Top Hits
# Track: WHERE SHE GOES - Artist: Bad Bunny
# Track: Dance The Night (From Barbie The Album) - Artist: Dua Lipa
# Track: Karma - Artist: Taylor Swift
# Track: Flowers - Artist: Miley Cyrus
# Track: Kill Bill - Artist: SZA
# Track: Popular (with Playboi Carti & Madonna) - Artist: The Weeknd
# Track: Calm Down (with Selena Gomez) - Artist: Rema
# Track: All My Life (feat. J. Cole) - Artist: Lil Durk
# Track: Peso Pluma: Bzrp Music Sessions, Vol. 55 - Artist: Bizarrap
# Track: People - Artist: Libianca
# Track: Cupid - Twin Ver. - Artist: FIFTY FIFTY
# Track: Boy's a Liar Pt. 2 - Artist: PinkPantheress
# Track: As It Was - Artist: Harry Styles
# Track: Die For You - Remix - Artist: The Weeknd
# Track: Daylight - Artist: David Kushner
# Track: Chemical - Artist: Post Malone
# Track: Baby Don't Hurt Me - Artist: David Guetta
# Track: Creepin' (with The Weeknd & 21 Savage) - Artist: Metro Boomin
# Track: Eyes Closed - Artist: Ed Sheeran
# Track: Ella Baila Sola - Artist: Eslabon Armado
# ---
# Playlist: RapCaviar
# Track: bread & butter - Artist: Gunna
# Track: Ocean Spray - Artist: Moneybagg Yo
# Track: Search & Rescue - Artist: Drake
# Track: Pull Up (feat. 21 Savage) - Artist: Toosii
# Track: Annihilate (Spider-Man: Across the Spider-Verse) (Metro Boomin & Swae Lee, Lil Wayne, Offset) - Artist: Metro Boomin
# Track: All My Life (feat. J. Cole) - Artist: Lil Durk
# Track: Go Hard - Artist: Lil Baby
# Track: Peaches & Eggplants (feat. 21 Savage) - Artist: Young Nudy
# Track: Pissy (feat. Roddy Ricch, Nardo Wick) - Artist: Gucci Mane
# Track: War Bout It (feat. 21 Savage) - Artist: Lil Durk
# Track: Calling (Spider-Man: Across the Spider-Verse) (Metro Boomin & Swae Lee
# Track: Ella Baila Sola - Artist: Eslabon Armado
# ---
# Playlist: Viral 50 - USA
# Track: Part of Your World - From "The Little Mermaid" - Artist: Halle
# Track: Makeba - Artist: Jain
# Track: Point Me To The Slut's - Artist: Fendi
# Track: Blame Brett - Artist: The Beaches
# Track: Area Codes - Artist: Kali
# Track: The Lost Soul Down - Artist: NBSPLV
# Track: Ella Baila Sola - Artist: Eslabon Armado
# Track: GOOD LOYAL THOTS - Artist: Odetari
# Track: Little Girl Gone - Artist: CHINCHILLA
# Track: Hits Different - Artist: Taylor Swift
# Track: Giving Me - Artist: Jazzy
# Track: Keep Dat Nigga - Artist: Icandy
# Track: Eve, Psyche & The Bluebeard’s wife - Artist: LE SSERAFIM
# Track: MATHEMATICAL DISRESPECT - Artist: Lil Mabu
# Track: Jericho - Artist: Iniko
# Track: Past Lives - Artist: Farizki
# Track: I Know You - Artist: Faye Webster
# Track: un x100to - Artist: Grupo Frontera
# Track: CCC - Artist: Michelle Maciel
# Track: NARCISSISTIC PERSONALITY DISORDER - Artist: Odetari
# ---
# Playlist: New Music Friday
# Track: Peso Pluma: Bzrp Music Sessions, Vol. 55 - Artist: Bizarrap
# Track: Popular (with Playboi Carti & Madonna) - Artist: The Weeknd
# Track: Pull Up (feat. 21 Savage) - Artist: Toosii
# Track: WATATI (feat. Aldo Ranks) [From Barbie The Album] - Artist: KAROL G
# Track: Calling (Spider-Man: Across the Spider-Verse) (Metro Boomin & Swae Lee, NAV, feat. A Boogie Wit da Hoodie) - Artist: Metro Boomin
# Track: The Glass - Artist: Foo Fighters
# Track: bread & butter - Artist: Gunna
# Track: Keep It Low (feat. Future) - Artist: Moneybagg Yo
# Track: Sprinter - Artist: Dave
# Track: I like u - Artist: Tove Lo
# Track: Home To Another One - Artist: Madison Beer
# Track: Sittin' On Top Of The World - Artist: Burna Boy
# Track: Eat Your Man (with Nelly Furtado) - Artist: Dom Dolla
# Track: A Beautiful Game - Artist: Ed Sheeran
# Track: Halfway To Hell - Artist: Jelly Roll
# Track: PRESSURE - Artist: Machine Gun Kelly
# Track: I Can't Lie (with Kodak Black) - Artist: French Montana
# Track: Self Destruction Mode - Artist: The Chainsmokers
# Track: BEACHY - Artist: Daddy Yankee
# Track: PORSCHE TOPLESS - Artist: Kid Cudi
# ---

# %%
regions = [ 'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming' ]
# Set the limit for the number of top tracks per region
limit = 20
# Iterate over the regions
for region in regions:
    # Get the popular playlists for the specific region
    playlists = sp.search(q=f'top tracks {region}', type='playlist', limit=1)['playlists']['items']
    if len(playlists) > 0:
        playlist_id = playlists[0]['id']
        playlist_name = playlists[0]['name']
        # Get the tracks of the playlist
        tracks = sp.playlist_tracks(playlist_id, limit=limit)['items']
        # Print the region and its top tracks
        print(f'Region: {region}')
        print(f'Playlist: {playlist_name}')
        for track in tracks:
            track_name = track['track']['name']
            artist_name = track['track']['artists'][0]['name']
            print(f'Track: {track_name} - Artist: {artist_name}')
        print('---')
    else:
        print(f'No playlist found for {region}.')

# %%
import pandas as pd
track_dataframe = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})
print(track_dataframe.shape)
track_dataframe.head(25)
# Out:
# (1000, 4)
#        artist_name                                         track_name  \
# 0              SZA                                          Kill Bill
# 1     Metro Boomin             Creepin' (with The Weeknd & 21 Savage)
# 2     Taylor Swift                                          Anti-Hero
# 3    Natanael Cano                                                AMG
# 4       Zach Bryan                            Something in the Orange
# 5     Metro Boomin  Superhero (Heroes & Villains) [with Future & C...
# 6            Drake                                          Rich Flex
# 7     Lil Uzi Vert                                    Just Wanna Rock
# 8              SZA                                             Snooze
# 9             Rema                      Calm Down (with Selena Gomez)
# 10    Metro Boomin            Trance (with Travis Scott & Young Thug)
# 11            d4vd                                  Romantic Homicide
# 12      NLE Choppa                                        SLUT ME OUT
# 13           Drake                      Jimmy Cooks (feat. 21 Savage)
# 14     OneRepublic                                    I Ain't Worried
# 15       Coi Leray                                            Players
# 16             SZA                                          Kill Bill
# 17  Lizzy McAlpine                                           ceilings
# 18    Taylor Swift                                              Karma
# 19            JVKE                                        golden hour
# 20       Bad Bunny                                    Me Porto Bonito
# 21           Drake                                        Spin Bout U
# 22          Future                    WAIT FOR U (feat. Drake & Tems)
# 23    Taylor Swift                                      Lavender Haze
# 24             SZA                                                Low
#
#                   track_id  popularity
# 0   1Qrg8KqiBpW07V7PNxwwwL          94
# 1   2dHHgzDwk4BJdRwy9uXhTO          95
# 2   0V3wPSX9ygBnCm8psDIegu          94
# 3   1lRtH4FszTrwwlK5gTSbXO          94
# 4   3WMj8moIAXJhHsyLaqIIHI          88
# 5   0vjeOZ3Ft5jvAi9SBFJm1j          90
# 6   1bDbXMyjaUIooNwFE9wn0N          90
# 7   4FyesJzVpA39hbYvcseO2d          90
# 8   4iZ4pt7kvcaH6Yo8UoZ4s2          92
# 9   0WtM2NBVQNNJLh6scP13H8          95
# 10  5wG3HvLhF6Y5KTGlK0IW3J          90
# 11  1xK59OXxi2TAAAbmZK0kBL          91
# 12  5BmB3OaQyYXCqRyN8iR2Yi          87
# 13  3F5CgOj3wFlRv51JsHbxhe          89
# 14  4h9wh7iOZ0GGn8QVp4RAOB          94
# 15  6UN73IYd0hZxLi8wFPMQij          91
# 16  3OHfY25tqY28d16oZczHc8          91
# 17  2L9N0zZnd37dwF0clgxMGI          90
# 18  7KokYm8cMIXCsGVmUvKtqf          89
# 19  5odlY52u43F5BjByhxg7wg          90
# 20  6Sq7ltF9Qa7SNFBsV5Cogx          92
# 21  2ZL7WZcjuYKi1KUDtp4kCC          85
# 22  59nOXPmaKlBfGMDeOVGrIK          87
# 23  5jQI2r1RdgtuT8S3iG8zFC          88
# 24  2GAhgAjOhEmItWLfgisyOn          87
